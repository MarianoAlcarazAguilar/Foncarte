# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web

# %%
gold = web.get_data_yahoo("GLD",
                            start = "2000-01-01")

# %%
gold
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2004-11-18   44.490002   44.070000   44.430000   44.380001   5992000
# 2004-11-19   44.919998   44.470001   44.490002   44.779999  11655300
# 2004-11-22   44.970001   44.740002   44.750000   44.950001  11996000
# 2004-11-23   44.919998   44.720001   44.880001   44.750000   3169200
# 2004-11-24   45.049999   44.790001   44.930000   45.049999   6105100
# ...                ...         ...         ...         ...       ...
# 2022-10-10  156.350006  155.119995  155.940002  155.479996   6110800
# 2022-10-11  156.809998  154.919998  155.490005  155.160004   5306700
# 2022-10-12  156.289993  155.259995  155.509995  155.990005   3998500
# 2022-10-13  155.729996  152.919998  153.479996  154.910004   7083800
# 2022-10-14  154.199997  152.720001  154.020004  152.979996   5471900
#
#              Adj Close
# Date
# 2004-11-18   44.380001
# 2004-11-19   44.779999
# 2004-11-22   44.950001
# 2004-11-23   44.750000
# ...

# %%
gold=gold.drop(['Low', 'High','Open','Volume','Close'], axis=1)

# %%
gold['Adj Close'].plot()
plt.xlabel("Date")
plt.ylabel("Adjusted")
plt.title("Gold Price data")
plt.show()

# %%
daily_returns = gold['Adj Close'].pct_change()

# %%
daily_returns.tolist()
# Out:
# [nan,
#  0.00901301715986258,
#  0.0037963820517381563,
#  -0.004449405106670246,
#  0.006703893565598751,
#  0.005327451332548749,
#  0.002428805655286581,
#  -0.00616745781020589,
#  0.005762458829464467,
#  -0.009475546387280875,
#  0.014460460514998497,
#  -0.00942983156939825,
#  -0.0013282612580445274,
#  -0.02438488747362011,
#  -0.005226074778644008,
#  -0.0077661069453631715,
#  0.010819549621581936,
#  -0.008198601949500617,
#  0.010103385743157833,
#  -0.00704708709849311,
#  0.011675785667812244,
#  0.003394467765116538,
#  -0.002706335847357022,
#  -0.00452285747214809,
#  0.005679236651527697,
#  0.004743597973824398,
#  -0.0024730353301175567,
#  -0.016001782771341122,
#  0.0038937696801815136,
#  -0.0006845218512604445,
#  -0.017808191618343572,
#  -0.006508572206357255,
#  -0.0016378920629933624,
#  -0.012186469776904074,
#  -0.007354717961295498,
#  0.0026290776756787704,
#  0.006197814464949936,
#  0.009239502442725867,
#  0.0,
#  -0.00657274153347609,
#  0.0,
# ...

# %%
gold["daily_return"]=daily_returns.tolist()

# %%
gold
# Out:
#              Adj Close  daily_return
# Date
# 2004-11-18   44.380001           NaN
# 2004-11-19   44.779999      0.009013
# 2004-11-22   44.950001      0.003796
# 2004-11-23   44.750000     -0.004449
# 2004-11-24   45.049999      0.006704
# ...                ...           ...
# 2022-10-10  155.479996     -0.015201
# 2022-10-11  155.160004     -0.002058
# 2022-10-12  155.990005      0.005349
# 2022-10-13  154.910004     -0.006924
# 2022-10-14  152.979996     -0.012459
#
# [4508 rows x 2 columns]

# %%
gold['daily_return'].plot(title='gold daily returns')
# Out:
# <AxesSubplot:title={'center':'gold daily returns'}, xlabel='Date'>

# %%
gold['Adj Close'].plot(title='Gold Price')
# Out:
# <AxesSubplot:title={'center':'Gold Price'}, xlabel='Date'>

# %%
gold.reset_index(inplace=True)

# %%
gold.to_csv('../gold.csv',header=True,index=False)
