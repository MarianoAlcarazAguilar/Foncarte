# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import unidecode

# %%
soup = BeautifulSoup(open("../datasets/source_code_mutual_art.html"))

# %%
obras = soup.findAll("div",{"class":"item table-row row v2__page"})
precios_fecha=[['precio estimado','precio_venta','fecha','autor','casa subasta','tipo','tecnica','dimensiones']]
for obra in obras:
    features=obra.findAll(lambda tag: tag.name=='div' and tag.get("class")==['v2__artwork-detail__price-col'])
    datos_obra=obra.findAll(lambda tag: tag.get("class")==['v2__link--primary'])
    tecnica = obra.findAll("span", {"itemprop": "artMedium"})
    dimensiones = obra.findAll("span", {"itemprop": "artDimensions"})
    if (len(features)==3 and len(datos_obra)==3 and len(tecnica)==1 and len(dimensiones)>=1):
        precio_estimado=features[0].text
        precio_venta=features[1].text
        fecha=features[2].text
        autor=datos_obra[0].text
        casa_subasta=datos_obra[1].text
        tipo=datos_obra[2].text
        tecnica=tecnica[0].text
        dimensiones=dimensiones[0].text
        precios_fecha.append([precio_estimado,precio_venta,fecha,autor,casa_subasta,tipo,tecnica,dimensiones])
    else:
        pass

# %%
len(precios_fecha)
# Out:
# 1227

# %%
data=pd.DataFrame(precios_fecha[1:],columns=precios_fecha[0])

# %%
for column in data.columns:
    data[str(column)]=data[str(column)].replace(r'\s+', ' ', regex=True)
    data[str(column)]=data[unidecode.unidecode(str(column))]

# %%
data
# Out:
#           precio estimado           precio_venta           fecha  \
# 0      2,000 - 3,000 EUR               Upcoming    Oct 13, 2022
# 1          500 - 800 EUR               Upcoming    Oct 13, 2022
# 2          600 - 900 EUR               Upcoming    Oct 13, 2022
# 3      1,500 - 2,500 EUR               Upcoming    Oct 13, 2022
# 4      1,500 - 2,500 EUR               Upcoming    Oct 13, 2022
# ...                   ...                    ...             ...
# 1221          90,000 BRL    Results Coming Soon    Sep 14, 2022
# 1222          48,000 BRL    Results Coming Soon    Sep 14, 2022
# 1223          35,000 BRL    Results Coming Soon    Sep 14, 2022
# 1224          45,000 BRL    Results Coming Soon    Sep 14, 2022
# 1225          10,000 BRL    Results Coming Soon    Sep 14, 2022
#
#                        autor   casa subasta                  tipo  \
# 0             Sergio Larrain       Finarte            Photographs
# 1              Martin Chambi       Finarte            Photographs
# 2            Jorge Friedmann       Finarte            Photographs
# 3                  Leo Matiz       Finarte            Photographs
# 4                  Leo Matiz       Finarte            Photographs
# ...                      ...            ...                   ...
# 1221        Arthur Luiz Piza  Aloisio Cravo  ART AUCTION (Online)
# 1222           Mira Schendel  Aloisio Cravo  ART AUCTION (Online)
# 1223         Emmanuel Nassar  Aloisio Cravo  ART AUCTION (Online)
# 1224         Emmanuel Nassar  Aloisio Cravo  ART AUCTION (Online)
# 1225   José António da Silva  Aloisio Cravo  ART AUCTION (Online)
#
#                                                 tecnica  \
# 0                         Vintage gelatin silver print
# 1                         Vintage gelatin silver print
# 2                         Vintage gelatin silver print
# 3                                        Digital print
# 4                                        Digital print
# ...                                                 ...
# 1221                              collage on cardboard
# 1222                    ecoline, letterset and collage
# 1223                                       sheet metal
# 1224   industrial paint on wood and aluminum sheet, ...
# 1225                                     oil on canvas
#
#                               dimensiones
# 0             12.2 x 8.3 in 8.3 x 8.3 in
# 1                2.6 x 2.4 in 2.2 x 2 in
# 2                             9.4 x 7 in
# 3      16.2 x 11.6 in 12.4 x 9.3 in 10 "
# 4      16.5 x 11.6 in 13.4 x 9.8 in 10 "
# ...                                   ...
# 1221                        37,5 x 28 cm
# 1222                      48,2 x 23,8 cm
# 1223                          90 x 90 cm
# 1224                    100 x 250 x 7 cm
# 1225                          43 x 58 cm
#
# [1226 rows x 8 columns]

# %%
data.to_csv('../datasets/data_mutualart_mariano.csv')
