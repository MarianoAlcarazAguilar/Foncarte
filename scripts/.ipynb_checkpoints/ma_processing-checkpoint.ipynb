# %%
import pandas as pd
import numpy as np
import re
from calendar import month_abbr

import unicodedata

# %% [markdown]
# # Procesamiento de los datos obtenidos de Mutual Art
#
# En este notbeook se limpiaron las categorías: autor, precio_venta, fecha, autor, tipo, tecnica y dimensiones. No se limpió casa subasta y las otras columnas de precios (están en otra ubicación en el repositorio).
#
# Es importante mencionar que esta limpieza se llevó a cabo con el archivo de MutualArtLimpio que contiane 3962 registros.

# %% [markdown]
# ## TO-DO
#
# - añadir función que cambia el nombre de las columnas y se queda solo con las que nos importa
#
# ### aspectos a mejorar
#
# - que se tome en cuenta si los primeros 2 datos son cm (actualmente se asume que son pulgadas)
#   - ej: 27x25 cm (10x5 in)
#   - en los datos usados para la muestra no se encontraron ejemplos donde sucediera esto
# - sacar promedio para el precio estimado

# %% [markdown]
# # limpieza de datos

# %%
def get_sold(df):
    
    sold = df[df['precio_venta'].str.contains('upcoming', case =False) == False]
    sold = sold[sold['precio_venta'].str.contains('live now', case =False) == False]
    sold = sold[sold['precio_venta'].str.contains('results coming soon', case =False) == False]
    sold = sold[sold['precio_venta'].str.contains('not sold', case =False) == False]
    
    return sold

# %%
df = pd.read_csv('../datasets/MutualArtLimpio.csv')
df_2 = pd.read_csv('../datasets/data_mutualart_completo.csv')


df_artistas = pd.read_csv('../datasets/lista_artistas.csv', encoding='utf8')

df = get_sold(df)
df_2 = get_sold(df_2)

# %%
#df_2.autor.unique() #641 authors

# %%
df.columns
# Out:
# Index(['ID', 'precio estimado', 'precio_venta', 'fecha', 'autor',
#        'casa subasta', 'tipo', 'tecnica', 'dimensiones',
#        'precio estimado dolares', 'precio venta dolares', 'is_inch', 'height',
#        'width'],
#       dtype='object')

# %% [markdown]
# # Clean date
#
# - existen mejores formas de hacer esto

# %%
def clean_date(df_orig):
    '''
    Cambia el formato a YYYY-MM-DD
    '''
    lower_ma = [m.lower() for m in month_abbr]
    df = df_orig.copy()
    
    df['fecha'] = df['fecha'].str.lower()
    
    months = df['fecha'].str.extract('([a-z]{3})') 
    #months = months[0].str.lower().map(lambda m: lower_ma.index(m)).astype('Int8')
    #years = df['fecha'].str.extract('([0-9]{4})')
    #days = df['fecha'].str.extract('([0-9]{2}),')

    #df['fecha'] = years[0]+'-'+months.astype(str)+'-'+days[0]
    #df['fecha'] = pd.to_datetime(df['fecha'])
    
    return months

# %%
df_clean = clean_date(df_2)
df_clean
# Out:
#          0
# 807    sep
# 920    sep
# 921    sep
# 922    sep
# 923    sep
# ...    ...
# 20119  mar
# 20120  mar
# 20122  mar
# 20123  mar
# 20124  mar
#
# [14392 rows x 1 columns]

# %% [markdown]
# # Clean tipo
#
# ### De tipo:
# (simplificarlo para solo incluir ciertas keywords)
# Vale la pena decir que hay varios que contienen más de una categoría. El órden para asignar la categoría es completamente arbitrario. Esto crea un sesgo a los datos.
#
# Para siguientes iteraciones, habría que ver como se almacenarían varios tipos a la vez. Otra sugerencia sería encontrar otra forma de determinar estas categorías y para determinar las categorías.
# - latin american
# - contemporary
# - modern
# - fine art
# - impressionist
# - auction
# - online
# - decorative
# - interiors
# - european
# - american
#
# Con estas 11 categorías se capturan 3619 de 3962 registros. Sobran 191 tipos. Del resto, no se detectaron patrones claros en esos tipos.

# %%
df.shape
# Out:
# (3962, 14)

# %%
def clean_tipo(df):
    '''
    "simplifica" la columna tipo. Se definieron 11 categorías principales
    que capturan aproc el 90% de los datos. 
    '''
    arr_tipos = ['latin america', 'contemporary', 'modern', 'fine art', 'impressionist',
                'auction', 'online', 'decorative', 'interiors', 'european', 'american']
    
    latam = df[df['tipo'].str.contains('latin america') == True] #2144 contienen 'latin america'
    cont = df[df['tipo'].str.contains('contemporary') == True] # 732 contienen 'contemporary'
    modern = df[df['tipo'].str.contains('modern') == True] # 799 contienen 'modern'
    fine_art = df[df['tipo'].str.contains('fine art') == True] # 156 contienen 'fine art'
    impr = df[df['tipo'].str.contains('impressionist') == True] # 202 contienen 'impressionist'
    #las siguientes categorías se obtuvieron examinando los registros que no pertenecían a alguna de las anteriores.
    # #s probable que información se haya perdido
    # quedaron 747 registros
    auct = df[df['tipo'].str.contains('auction') == True] # 501 contienen 'auction'
    online = df[df['tipo'].str.contains('online') == True] # 142 contienen 'online'
    decor = df[df['tipo'].str.contains('decorative') == True] # 74 contienen 'decorative'
    interiors = df[df['tipo'].str.contains('interiors') == True] # 30 contienen 'interiors'
    eur = df[df['tipo'].str.contains('european') == True] # 96 contienen 'european'
    american = df[df['tipo'].str.contains('american') == True] # 87 contienen 'american' pero no 'latin'
    
    df = pd.concat([latam, cont, modern, fine_art, impr, auct, online, decor, interiors, eur, american])
    df = df.drop_duplicates()
    
    return df

#to-do
#- cambiar el valor a los tipos de acuerdo con como se registraron

# %%
test_tipo = clean_tipo(df)
test_tipo
# Out:
#         ID              precio estimado      precio_venta  \
# 1257  1258    2,200,000 - 4,000,000 mxn    2,000,000 mxn*
# 1258  1259        480,000 - 600,000 mxn      450,000 mxn*
# 1288  1289  48,000,000 - 60,000,000 cop  240,000,000 cop*
# 1297  1298          70,000 - 90,000 usd       163,800 usd
# 1298  1299        100,000 - 150,000 usd       239,400 usd
# ...    ...                          ...               ...
# 4615  4616            4,000 - 6,000 usd         7,930 usd
# 4737  4738           6,000 - 10,000 usd         5,000 usd
# 3018  3019                300 - 500 usd         1,380 usd
# 3966  3967            6,000 - 9,000 usd        3,750 usd*
# 4840  4841              900 - 1,200 usd         1,560 usd
#
#                             fecha                    autor  \
# 1257                 jun 02, 2022                  dr. atl
# 1258                 jun 02, 2022    jesus guerrero galvan
# 1288                 apr 07, 2022        alejandro obregon
# 1297                 mar 11, 2022       oswaldo guayasamin
# 1298                 mar 11, 2022        alejandro obregon
# ...                           ...                      ...
# 4615                 nov 13, 2010  graciela rodo boulanger
# 4737                 jun 21, 2009         francisco zuniga
# 3018                 may 14, 2002            angel botello
# 3966  apr 08, 2016 - apr 09, 2016             diego rivera
# 4840                 dec 16, 2007            rufino tamayo
#
#                                  casa subasta  \
# 1257          morton auctions, cerro de mayka
# 1258          morton auctions, cerro de mayka
# 1288                            bogotauctions
# 1297                      christie's new york
# 1298                      christie's new york
# ...                                       ...
# 4615             rago arts and auction center
# 4737                                freeman's
# 3018                                   wright
# 3966  eldred's auction and appraisal services
# 4840            altermann galleries, santa fe
#
#                                                    tipo  \
# 1257                         latin american art auction
# 1258                         latin american art auction
# 1288  colombian and latin american art, modern and c...
# 1297                                 latin american art
# 1298                                 latin american art
# ...                                                 ...
# 4615          19th/20th century american & european art
# 4737                      american & european paintings
# 3018          american art including the american scene
# 3966                              americana & paintings
# 4840                                american indian art
#
#                         tecnica                         dimensiones  \
# 1257            oil on masonite                          35 x 52 cm
# 1258  tempera on canvas on wood                        77.3 x 66 cm
# 1288              oil on canvas                        39 x 49,5 cm
# 1297              oil on canvas  47 1a4 x 29 3a8 in. 120 x 74.5 cm.
# 1298              oil on canvas    32 x 39 1a2 in. 81.3 x 100.3 cm.
# ...                         ...                                 ...
# 4615              oil on canvas                         32" x 25.5"
# 4737       copper relief plaque                      21.75 x 30 in.
# 3018               scratchboard                    15 x 12.5 inches
# 3966               oil on board                      13.25" x 10.5"
# 4840                mixed media                         9.5 by 6.75
#
#      precio estimado dolares precio venta dolares  is_inch  height  width
# 1257                200000.0             100000.0        0   35.00  52.00
# 1258                 30000.0              22500.0        0   77.30  66.00
# 1288                 13200.0              52800.0        0   39.00  49.00
# 1297                 90000.0             163800.0        1   47.00   1.00
# 1298                150000.0             239400.0        1   32.00  39.00
# ...                      ...                  ...      ...     ...    ...
# 4615                  6000.0               7930.0        1   32.00  25.50
# 4737                 10000.0               5000.0        1   21.75  30.00
# 3018                   500.0               1380.0        1   15.00  12.50
# 3966                  9000.0               3750.0        1   13.25  10.50
# 4840                  1200.0               1560.0        1    9.50   6.75
#
# [3619 rows x 14 columns]

# %%
df_tipo = df[df['tipo'].str.contains('latin america') == False] #2144 contienen 'latin america'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('contemporary') == False] # 732 contienen 'contemporary'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('modern') == False] # 799 contienen 'modern'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('fine art') == False] # 156 contienen 'fine art'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('impressionist') == False] # 202 contienen 'impressionist'
#las siguientes categorías se obtuvieron examinando los registros que no pertenecían a alguna de las anteriores.
# #s probable que información se haya perdido
# quedaron 747 registros
df_tipo = df_tipo[df_tipo['tipo'].str.contains('auction') == False] # 501 contienen 'auction'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('online') == False] # 142 contienen 'online'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('decorative') == False] # 74 contienen 'decorative'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('interiors') == False] # 30 contienen 'interiors'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('european') == False] # 96 contienen 'european'
df_tipo = df_tipo[df_tipo['tipo'].str.contains('american') == False] # 87 contienen 'american' pero no 'latin'

df_tipo
# Out:
#         ID      precio estimado precio_venta         fecha  \
# 976    977    1,000 - 1,500 gbp    1,275 gbp  sep 20, 2022
# 1030  1031    2,500 - 4,000 mxn   3,200 mxn*  sep 17, 2022
# 1031  1032  10,000 - 20,000 mxn   8,000 mxn*  sep 17, 2022
# 1039  1040  15,000 - 25,000 mxn  14,000 mxn*  sep 17, 2022
# 1041  1042    4,000 - 8,000 mxn   3,800 mxn*  sep 17, 2022
# ...    ...                  ...          ...           ...
# 5059  5060    5,000 - 7,000 eur    5,975 eur  may 28, 2002
# 5060  5061    4,000 - 6,000 eur    4,780 eur  may 28, 2002
# 5073  5074    2,500 - 4,500 usd    2,800 usd  nov 13, 2001
# 5135  5136         25 - 200 gbp      126 gbp  feb 25, 1999
# 5136  5137    2,500 - 3,000 gbp    2,530 gbp  dec 07, 1998
#
#                      autor                  casa subasta  \
# 976          raul anguiano         bonhams knightsbridge
# 1030           jorge coste  morton auctions, monte athos
# 1031         torrico prado  morton auctions, monte athos
# 1039  carlos orozco romero  morton auctions, monte athos
# 1041          emilio behar  morton auctions, monte athos
# ...                    ...                           ...
# 5059         antonio segui          christie's amsterdam
# 5060         antonio segui          christie's amsterdam
# 5073     leopoldo romanach                doyle new york
# 5135    cesar a. villacres   christie's south kensington
# 5136     rene portocarrero   christie's south kensington
#
#                                       tipo  \
# 976                   travel & exploration
# 1030  morton saturdays. opportunities 1156
# 1031  morton saturdays. opportunities 1156
# 1039  morton saturdays. opportunities 1156
# 1041  morton saturdays. opportunities 1156
# ...                                    ...
# 5059                 twentieth century art
# 5060                 twentieth century art
# 5073             20th century art & design
# 5135      british and continental pictures
# 5136                 twentieth century art
#
#                                      tecnica                      dimensiones  \
# 976                            oil on canvas     65.1 x 50.2cm (25 x 19.75in)
# 1030  made of bronze, with black marble base                  25 x 25 x 10 cm
# 1031                           oil on canvas                       69 x 59 cm
# 1039             ink pencil drawing on paper                   28.5 x 20.5 cm
# 1041            digital photography on rigid                       90 x 60 cm
# ...                                      ...                              ...
# 5059                          oil on plywood                    82.5 x 113 cm
# 5060                           oil on canvas                      61 x 100 cm
# 5073                      oil on canvasboard              8.5 x 14.625 inches
# 5135                           oil on canvas      15 x 12in. (39.3 x 30.5cm.)
# 5136                oil and gouache on paper  230.75 x 130.75in. (60 x 35cm.)
#
#      precio estimado dolares precio venta dolares  is_inch  height    width
# 976                   1620.0               1377.0        1   65.10   50.200
# 1030                   200.0                160.0        0   25.00   25.000
# 1031                  1000.0                400.0        0   69.00   59.000
# 1039                  1250.0                700.0        0   28.50   20.500
# 1041                   400.0                190.0        0   90.00   60.000
# ...                      ...                  ...      ...     ...      ...
# 5059                  6790.0              5795.75        0   82.50  113.000
# 5060                  5820.0    4636.599999999999        0   61.00  100.000
# 5073                  4500.0               2800.0        1    8.50   14.625
# 5135                   216.0               136.08        1   15.00   12.000
# 5136                  3240.0               2732.4        1  230.75  130.750
#
# [343 rows x 14 columns]

# %%
df_tipo.groupby(by=['tipo']).count().sort_values(by='ID', ascending= False).head(40)#.tail(20)
# Out:
#                                                     ID  precio estimado  \
# tipo
# the house sale                                      12               12
# 20th century art & design                           11               11
# national paintings                                   9                9
# national painting                                    8                8
# mexican art                                          7                7
# fine paintings & sculpture                           7                7
# 20th century art and design                          6                6
# international art                                    6                6
# morton saturdays. opportunities 1156                 6                6
# new now                                              5                5
# art & design                                         5                5
# estate jewelry, art & collectibles                   5                5
# doyle at home®                                       5                5
# 20 | 21 art                                          5                5
# paintings                                            5                5
# foreign painting                                     4                4
# haitian paintings                                    4                4
# optical and geometrical collection – important ...   4                4
# 20|21 art                                            4                4
# painting, drawing and sculpture                      4                4
# made in mexico                                       3                3
# art d'apraas-guerre et contemporain                  3                3
# doyle at home                                        3                3
# 20th century art + design                            3                3
# twentieth century art                                3                3
# prints & multiples                                   3                3
# living with art                                      3                3
# humanus versus animal                                3                3
# arcade paintings                                     3                3
# british and continental pictures                     3                3
# july splendor 2022 - day 3                           3                3
# post-war to present                                  3                3
# naples                                               3                3
# doyle+design®                                        2                2
# dr. g & the kaufman collection                       2                2
# paris avant-garde                                    2                2
# paintings, prints, drawings and sculpture            2                2
# fine portrait miniatures                             2                2
# palm beach collections                               2                2
# paintings, sculptures, watercolors, drawings an...   2                2
#
#                                                     precio_venta  fecha  \
# tipo
# the house sale                                                12     12
# 20th century art & design                                     11     11
# national paintings                                             9      9
# national painting                                              8      8
# mexican art                                                    7      7
# fine paintings & sculpture                                     7      7
# 20th century art and design                                    6      6
# international art                                              6      6
# morton saturdays. opportunities 1156                           6      6
# new now                                                        5      5
# art & design                                                   5      5
# estate jewelry, art & collectibles                             5      5
# doyle at home®                                                 5      5
# 20 | 21 art                                                    5      5
# paintings                                                      5      5
# foreign painting                                               4      4
# haitian paintings                                              4      4
# optical and geometrical collection – important ...             4      4
# 20|21 art                                                      4      4
# painting, drawing and sculpture                                4      4
# made in mexico                                                 3      3
# art d'apraas-guerre et contemporain                            3      3
# doyle at home                                                  3      3
# 20th century art + design                                      3      3
# twentieth century art                                          3      3
# prints & multiples                                             3      3
# living with art                                                3      3
# humanus versus animal                                          3      3
# arcade paintings                                               3      3
# british and continental pictures                               3      3
# july splendor 2022 - day 3                                     3      3
# post-war to present                                            3      3
# naples                                                         3      3
# doyle+design®                                                  2      2
# dr. g & the kaufman collection                                 2      2
# paris avant-garde                                              2      2
# paintings, prints, drawings and sculpture                      2      2
# fine portrait miniatures                                       2      2
# palm beach collections                                         2      2
# paintings, sculptures, watercolors, drawings an...             2      2
#
#                                                     autor  casa subasta  \
# tipo
# the house sale                                         12            12
# 20th century art & design                              11            11
# national paintings                                      9             9
# national painting                                       8             8
# mexican art                                             7             7
# fine paintings & sculpture                              7             7
# 20th century art and design                             6             6
# international art                                       6             6
# morton saturdays. opportunities 1156                    6             6
# new now                                                 5             5
# art & design                                            5             5
# estate jewelry, art & collectibles                      5             5
# doyle at home®                                          5             5
# 20 | 21 art                                             5             5
# paintings                                               5             5
# foreign painting                                        4             4
# haitian paintings                                       4             4
# optical and geometrical collection – important ...      4             4
# 20|21 art                                               4             4
# painting, drawing and sculpture                         4             4
# made in mexico                                          3             3
# art d'apraas-guerre et contemporain                     3             3
# doyle at home                                           3             3
# 20th century art + design                               3             3
# twentieth century art                                   3             3
# prints & multiples                                      3             3
# living with art                                         3             3
# humanus versus animal                                   3             3
# arcade paintings                                        3             3
# british and continental pictures                        3             3
# july splendor 2022 - day 3                              3             3
# post-war to present                                     3             3
# naples                                                  3             3
# doyle+design®                                           2             2
# dr. g & the kaufman collection                          2             2
# paris avant-garde                                       2             2
# paintings, prints, drawings and sculpture               2             2
# fine portrait miniatures                                2             2
# palm beach collections                                  2             2
# paintings, sculptures, watercolors, drawings an...      2             2
#
#                                                     tecnica  dimensiones  \
# tipo
# the house sale                                           12           12
# 20th century art & design                                11           11
# national paintings                                        9            9
# national painting                                         8            8
# mexican art                                               7            7
# fine paintings & sculpture                                7            7
# 20th century art and design                               6            6
# international art                                         6            6
# morton saturdays. opportunities 1156                      6            6
# new now                                                   5            5
# art & design                                              5            5
# estate jewelry, art & collectibles                        5            5
# doyle at home®                                            5            5
# 20 | 21 art                                               5            5
# paintings                                                 5            5
# foreign painting                                          4            4
# haitian paintings                                         4            4
# optical and geometrical collection – important ...        4            4
# 20|21 art                                                 4            4
# painting, drawing and sculpture                           4            4
# made in mexico                                            3            3
# art d'apraas-guerre et contemporain                       3            3
# doyle at home                                             3            3
# 20th century art + design                                 3            3
# twentieth century art                                     3            3
# prints & multiples                                        3            3
# living with art                                           3            3
# humanus versus animal                                     3            3
# arcade paintings                                          3            3
# british and continental pictures                          3            3
# july splendor 2022 - day 3                                3            3
# post-war to present                                       3            3
# naples                                                    3            3
# doyle+design®                                             2            2
# dr. g & the kaufman collection                            2            2
# paris avant-garde                                         2            2
# paintings, prints, drawings and sculpture                 2            2
# fine portrait miniatures                                  2            2
# palm beach collections                                    2            2
# paintings, sculptures, watercolors, drawings an...        2            2
#
#                                                     precio estimado dolares  \
# tipo
# the house sale                                                           12
# 20th century art & design                                                11
# national paintings                                                        9
# national painting                                                         8
# mexican art                                                               7
# fine paintings & sculpture                                                7
# 20th century art and design                                               6
# international art                                                         6
# morton saturdays. opportunities 1156                                      6
# new now                                                                   5
# art & design                                                              5
# estate jewelry, art & collectibles                                        5
# doyle at home®                                                            5
# 20 | 21 art                                                               5
# paintings                                                                 5
# foreign painting                                                          4
# haitian paintings                                                         4
# optical and geometrical collection – important ...                        4
# 20|21 art                                                                 4
# painting, drawing and sculpture                                           4
# made in mexico                                                            3
# art d'apraas-guerre et contemporain                                       3
# doyle at home                                                             3
# 20th century art + design                                                 3
# twentieth century art                                                     3
# prints & multiples                                                        3
# living with art                                                           3
# humanus versus animal                                                     3
# arcade paintings                                                          3
# british and continental pictures                                          3
# july splendor 2022 - day 3                                                3
# post-war to present                                                       3
# naples                                                                    3
# doyle+design®                                                             2
# dr. g & the kaufman collection                                            2
# paris avant-garde                                                         2
# paintings, prints, drawings and sculpture                                 2
# fine portrait miniatures                                                  2
# palm beach collections                                                    2
# paintings, sculptures, watercolors, drawings an...                        2
#
#                                                     precio venta dolares  \
# tipo
# the house sale                                                        12
# 20th century art & design                                             11
# national paintings                                                     9
# national painting                                                      8
# mexican art                                                            7
# fine paintings & sculpture                                             7
# 20th century art and design                                            6
# international art                                                      6
# morton saturdays. opportunities 1156                                   6
# new now                                                                5
# art & design                                                           5
# estate jewelry, art & collectibles                                     5
# doyle at home®                                                         5
# 20 | 21 art                                                            5
# paintings                                                              5
# foreign painting                                                       4
# haitian paintings                                                      4
# optical and geometrical collection – important ...                     4
# 20|21 art                                                              4
# painting, drawing and sculpture                                        4
# made in mexico                                                         3
# art d'apraas-guerre et contemporain                                    3
# doyle at home                                                          3
# 20th century art + design                                              3
# twentieth century art                                                  3
# prints & multiples                                                     3
# living with art                                                        3
# humanus versus animal                                                  3
# arcade paintings                                                       3
# british and continental pictures                                       3
# july splendor 2022 - day 3                                             3
# post-war to present                                                    3
# naples                                                                 3
# doyle+design®                                                          2
# dr. g & the kaufman collection                                         2
# paris avant-garde                                                      2
# paintings, prints, drawings and sculpture                              2
# fine portrait miniatures                                               2
# palm beach collections                                                 2
# paintings, sculptures, watercolors, drawings an...                     2
#
#                                                     is_inch  height  width
# tipo
# the house sale                                           12      12     12
# 20th century art & design                                11      11     11
# national paintings                                        9       9      9
# national painting                                         8       8      8
# mexican art                                               7       7      7
# fine paintings & sculpture                                7       7      7
# 20th century art and design                               6       6      6
# international art                                         6       6      6
# morton saturdays. opportunities 1156                      6       6      6
# new now                                                   5       5      5
# art & design                                              5       5      5
# estate jewelry, art & collectibles                        5       5      4
# doyle at home®                                            5       5      5
# 20 | 21 art                                               5       5      5
# paintings                                                 5       5      5
# foreign painting                                          4       4      4
# haitian paintings                                         4       4      4
# optical and geometrical collection – important ...        4       4      4
# 20|21 art                                                 4       4      4
# painting, drawing and sculpture                           4       4      4
# made in mexico                                            3       3      3
# art d'apraas-guerre et contemporain                       3       3      3
# doyle at home                                             3       3      3
# 20th century art + design                                 3       3      3
# twentieth century art                                     3       3      3
# prints & multiples                                        3       3      3
# living with art                                           3       3      3
# humanus versus animal                                     3       3      3
# arcade paintings                                          3       3      3
# british and continental pictures                          3       3      3
# july splendor 2022 - day 3                                3       3      3
# post-war to present                                       3       3      3
# naples                                                    3       3      3
# doyle+design®                                             2       2      2
# dr. g & the kaufman collection                            2       2      2
# paris avant-garde                                         2       2      2
# paintings, prints, drawings and sculpture                 2       2      2
# fine portrait miniatures                                  2       2      2
# palm beach collections                                    2       2      2
# paintings, sculptures, watercolors, drawings an...        2       2      2

# %% [markdown]
# # Clean tecnica
# - sacar keywords???
# - mixed media en una
# - depende de las tecnicas del otro equipo

# %%
df.groupby(by=['tecnica']).count().sort_values(by='ID', ascending= False)head(10)
# Out:
#                                         ID  precio estimado  precio_venta  \
# tecnica
# mixed media on paper laid on canvas      1                1             1
# mixed media on paper mounted on canvas   1                1             1
# mixed media on paper/ canvas             1                1             1
# mixed media on pasteboard                1                1             1
# mixed media sketch                       1                1             1
# mixed media with metal, wood, painted    1                1             1
# mixed media work on masonite             1                1             1
# mixed media, gouache and watercolor      1                1             1
# mixed mediaoil and fabric on panel       1                1             1
# wood, black veneer, leather              1                1             1
#
#                                         fecha  autor  casa subasta  tipo  \
# tecnica
# mixed media on paper laid on canvas         1      1             1     1
# mixed media on paper mounted on canvas      1      1             1     1
# mixed media on paper/ canvas                1      1             1     1
# mixed media on pasteboard                   1      1             1     1
# mixed media sketch                          1      1             1     1
# mixed media with metal, wood, painted       1      1             1     1
# mixed media work on masonite                1      1             1     1
# mixed media, gouache and watercolor         1      1             1     1
# mixed mediaoil and fabric on panel          1      1             1     1
# wood, black veneer, leather                 1      1             1     1
#
#                                         dimensiones  precio estimado dolares  \
# tecnica
# mixed media on paper laid on canvas               1                        1
# mixed media on paper mounted on canvas            1                        1
# mixed media on paper/ canvas                      1                        1
# mixed media on pasteboard                         1                        1
# mixed media sketch                                1                        1
# mixed media with metal, wood, painted             1                        1
# mixed media work on masonite                      1                        1
# mixed media, gouache and watercolor               1                        1
# mixed mediaoil and fabric on panel                1                        1
# wood, black veneer, leather                       1                        1
#
#                                         precio venta dolares  is_inch  height  \
# tecnica
# mixed media on paper laid on canvas                        1        1       1
# mixed media on paper mounted on canvas                     1        1       1
# mixed media on paper/ canvas                               1        1       1
# mixed media on pasteboard                                  1        1       1
# mixed media sketch                                         1        1       1
# mixed media with metal, wood, painted                      1        1       1
# mixed media work on masonite                               1        1       1
# mixed media, gouache and watercolor                        1        1       1
# mixed mediaoil and fabric on panel                         1        1       1
# wood, black veneer, leather                                1        1       1
#
#                                         width
# tecnica
# mixed media on paper laid on canvas         1
# mixed media on paper mounted on canvas      1
# mixed media on paper/ canvas                1
# mixed media on pasteboard                   1
# mixed media sketch                          1
# mixed media with metal, wood, painted       1
# mixed media work on masonite                1
# mixed media, gouache and watercolor         1
# mixed mediaoil and fabric on panel          1
# wood, black veneer, leather                 1

# %%
#df['tipo'].unique()
df['tecnica'].unique()
# Out:
# array(['oil on canvas', 'screenprint on cardboard', 'mixed media',
#        'lithograph on guarro paper', 'mixed media on canvas',
#        'oil on canvas on hardboard', 'mixed media on linen',
#        'lithograph on wove paper', 'silverplate', 'o/c',
#        'digital graphic. silkscreen', 'seriograph',
#        'made of bronze, with black marble base',
#        'ink pencil drawing on paper', 'digital photography on rigid',
#        'acrylic, oil, enamel, adhesive tape, vinyl and paper collage on canvas',
#        'screen printing', 'lithograph', 'painting', 'screenprint',
#        'bronze sculpture', 'engraving or mezzotint',
#        'limited edition print', 'oil and gesso on board', 'oil on paper',
#        'rosewood, leather', 'etching and embossing', 'etching / aquatint',
#        'thermoformed plastic', 'oil on masonite', 'oil on board',
#        'tempera and crayon on cardboard', 'gouache on cardboard',
#        'tempera on canvas on wood', 'tempera on paperboard',
#        'tempera on cardboard', "oil on masonite in artist's frame",
#        'oil on wood', 'oil on panel',
#        'petroplastic and gold leaf on panel', 'oil and sand on canvas',
#        'tempera on masonite', 'gouache and charcoal on paper on canvas',
#        'acrylic on canvas',
#        'oil and tempera on canvas laid down on panel', 'tempera on board',
#        'stencil on cardboard', 'acrylic and sand on canvas', 'oil/plate',
#        'oil on canvas;', 'tempered on fiberboard',
#        'acrylic on cement panel', 'oil and lacquer on panel',
#        'tempera on etched and gold leafed paperboard',
#        'oil on unstretched canvas', 'mixed media on panel',
#        'oil on isorel', 'oil on artist board', 'painting on canvas',
#        'oil on cardboard', 'tempera on canvas on masonite',
#        'oil on canvas on wood', 'oil on paper laid to board',
#        'acrylic on canvas canvas', 'acrylic on masonite',
#        'oil on canvas.', 'gouache and watercolor on canvas',
#        'politec and resin on wood', 'oil and sand on masonite',
#        'oil and enamel paint on board laid on board',
#        'mixed media on pasteboard', 'temple on masonite',
#        'gouache and ink on card', 'oil on pressed pulpboard',
#        'oil on canvas laid on board',
#        'mixed media on canvas laid on wood',
#        'politec on parchment on panel',
#        'graphite, oil and oil pastel on canvas', 'oil on\xa0panel',
#        'painted ceramic', 'tempera on panel', 'mixed media on board',
#        'oil and tempera on masonite', 'oil on board laid on board',
#        'tempera', 'oil on canvas laid to upson board',
#        'oil on canvas painting', 'mixed media on wood',
#        'oil on wood panel', 'gouache on paper laid on board', 'gouache',
#        'acrylic on wood', 'painting in oil on canvas',
#        'brush and ink on board', 'oil and colored pencil on linen',
#        'oil on canvas on fiberglass', 'oil', 'oil painting on canvas',
#        'oil and atl colors on masonite', 'acrylic on linen',
#        'oil and sand on board', 'cuban/american; canvas',
#        'oil painting thin card artist mounted to wood panel',
#        'atl colors on masonite', 'oil, acrylic and graphite on canvas',
#        'mixed technique and relief', 'oil on plate',
#        'gold leaf, tempera and',
#        'acrylic on handmade paper laid down on masonite', 'oil on burlap',
#        'mixed on canvas', 'acrylic and stencil on cardboard',
#        'oil on\xa0board', 'oil on canvas (framed)',
#        'tempera on etched and gold leafed paper laid to cardboard',
#        'acrylic and color pencil on canvas', 'board',
#        'acrylic and silver paint on illustration board',
#        'pastel on masonite', 'oil on linen', 'acrylic on panel',
#        'oil on canvas mounted to board',
#        'gouache on paper laid down on board', 'oil and pencil on canvas',
#        'oil on canvas stretched over panel',
#        'oil on prepared plywood panel',
#        'oil painting on stretched burlap', 'acrylic painting on canvas',
#        'oil on paper laid down on masonite', 'scratchboard',
#        'oil on canvas laid on cardboard', 'oil relief on masonite',
#        'oil on paper on cardboard', 'acrylic and graphite on canvas',
#        'mixed technique on cardboard', 'scraper board',
#        'oil on hardboard', 'acrylic with sand on card',
#        'oil on canvas laid down on masonite',
#        'watercolor and gouache on cardboard', 'an abstract oil on canvas',
#        'gouache and india ink on paper laid down on canvas',
#        'oil on amate paper laid on board', 'tempera on canvas',
#        'oil on paper mounted on board', 'duco on masonite',
#        'mixed media on paper laid down on masonite',
#        'oil on wooden panel', 'acrylic & gilt on card',
#        "oil on artist's board", 'oil on canvas laid down on board',
#        'oil and graphite on linen', 'oil and acrylic on corrugated board',
#        'gouache and graphite on amate paper laid on masonite',
#        'oil on paperboard', 'tempera on cardboard corrugated',
#        'oil and tempera on thin cardboard laid down on triplay',
#        'oil and paper collage on board', 'oil on canvas laid on wood',
#        'oil on burlap mounted on panel', 'acrylic on mattresses',
#        'encaustic and oil on cardboard',
#        'petroplastic on panel; acrylic on panel; acrylic on paper; pencil and gouache on paper',
#        'oil on canvas mounted on board', 'oil and mixed media on canvas',
#        'mixed media on cardboard', 'mixed media, gouache and watercolor',
#        'acrylics on canvas', 'oil and graphite on canvas',
#        'color crayon on paper laid down on masonite',
#        'oil on heavy paper mounted on panel', 'petroplastic on wood',
#        'acrylic and silkscreen on canvas',
#        'acrylic, ink and graphite on canvas', 'acrylic on board',
#        'pastel on canvas', 'oil on fiber', 'mixed media on masonite',
#        'oil on corrugated cardboard mounted on canvas',
#        'oil on canvas, oil on paper',
#        'acrylic, oil and colored pencil on canvas', 'oil on wood board',
#        'mixed media on amate paper laid down on board',
#        'oil on board laid down on masonite',
#        'oil on masonite, in hand-carved haitian frame',
#        'petroplastic mounted on board',
#        'mixed media on paper laid down on board', 'oil on masonite board',
#        'oil on a wooden board', 'oil on canvas laid down on canvas',
#        'ink / gouache on card',
#        'oil on incised amate paper laid on masonite', 'casein on canvas',
#        'watercolor on board', 'oil on corrugated cardboard',
#        'atl-color on masonite', 'atl-color on jute', 'gouache on board',
#        'gouache and ink on artist board', 'oil\xa0on board',
#        'acrylic\xa0on canvas', 'oil\xa0on canvas',
#        'oil and atl colors on panel', 'casein on parchment',
#        'oil on canvas pasted on cardboard', 'mixed and cut metal panel',
#        'mixed media (oil and paper) on masonite',
#        'oil on paper laid on cardboard', 'oil and ink on canvas',
#        'charcoal on canvas', 'oil\xa0and mixed media on\xa0canvas',
#        'oil and atl-color', 'oil on compressed board',
#        'oil on canvas\xa0mounted to board',
#        'acrylic on linen, in two parts',
#        "oil on masonite, in artist's frame", 'oil on canvas board',
#        'gouache on paperboard', 'paintings', 'duco on cardboard',
#        'oil on board laid on masonite', 'oil on linen mounted on canvas',
#        'atl-color on compressed wood', 'oil and acrylic on canvas',
#        'atl-color and oil on kraft paper mounted on masonite',
#        'oil on canvas on masonite', 'oil on canvas and cable',
#        'oil and petroplastic on masonite', 'gouache and ink on board',
#        'oil on canvasboard', 'oil and petroplastic on wood',
#        'gouache and petroplastic on amate paper laid on board',
#        'oil and polytec on wood', 'petroplastic and oil on panel',
#        'oil on card', 'oil on canvas laid on paper board',
#        'scratch board', 'mixed media work on masonite',
#        'mixed media on amate paper laid down on masonite',
#        'oil on board mounted on metal plate',
#        'duco and sand on paper on board',
#        'gouache on paper laid down on canvas',
#        'gouache and petroplastic on handmade paper laid on board',
#        'watercolor and gouache on paper laid down on masonite, oil on canvas',
#        'oil and tempera on panel', 'oil on paper laid to masonite',
#        'gouache on illustration board', 'oil and ink on canvasboard',
#        'oil and gouache on paper laid on masonite',
#        'duco and sand on canvas',
#        "federico cantu (mexican 1908-1989) el retorno de ulises signed 'federico cantu' (lower right) oil on canvas laid on panel 23¾ x 31 3/8 in. (60.3 x 80 cm.)",
#        'oil and colors on masonite',
#        'oil on canvas laid down to card; oil on card',
#        'acrylic and colored pencil on canvas',
#        'oil and gold leaf on wood panel', 'acrylic on canvas board',
#        'mixed media and collage on cardboard',
#        'acrylic and oil on canvas',
#        'oil on canvas; ink and watercolor with graphite on paper',
#        'gouache on paper laid on masonite',
#        'oil and atl color on masonite', 'oil and graphite on masonite',
#        'graphite and acrylic on canvas',
#        'oil, wash and graphite on canvas',
#        'gouache and pencil on cream illustration board',
#        'acrylic and charcoal on canvas', 'oil on canvas, board',
#        'oil and polytec on panel', 'oil on canvas laid on canvas',
#        'gouache on paper laid on cardboard',
#        'acrylic on canvas in 11 parts.',
#        'a. oil on canvas, b. oil on board',
#        'duco and oil on heavy paper laid on panel',
#        'duco on parchment mounted on masonite',
#        'duco on heavy paper laid on board',
#        'casein on polished parchment with petroplastic on panel',
#        'oil on canvas laid down on cardboard',
#        "oil on masonite laid to 1/8'' plywood", 'tempera on wood',
#        'oil, pastel and gouache on masonite',
#        'oil and atl color (solid resin-based pigments) and tempera on masonite',
#        'oil on paper mounted on wood',
#        'oil, atl color (solid resin-based pigments) and tempera on wood panel',
#        'oil on canvas laid to masonite and backed by plywood in a hand-carved frame',
#        'oil on masonite in hand carved frame',
#        'oil and mixed media on board', 'oil on canvas on cardboard',
#        'temple on cardboard', 'oil on canvas mounted on wood',
#        'oil on canvas mounted on panel',
#        'gouache on paper mounted on masonite',
#        'watercolor pigment and wash on canvas',
#        'oil on canvas stretched on plywood',
#        'oil on canvas stretched around panel',
#        'tempera and beeswax varnish on wood panel',
#        'gouache on paper mounted on canvas',
#        'oil and tempera on heavy paper laid down on canvas',
#        'gouache on amate paper mounted on cardboard',
#        'resin and oil on parchment mounted on wood', 'duco on board',
#        'gouache and watercolor on paper laid down on board',
#        'acrylic and coloured pencil on canvas',
#        'oil on paper laid down on canvas',
#        'oil and wax crayons on canvas', 'oil and gold paint on masonite',
#        'oil on board laid down on canvas',
#        'oil on canvas affixed to panel',
#        'oil on paper laid down on board',
#        'acrylic and polytec on masonite', 'atl colors on board',
#        "gouache on artist's board", 'gouache and chalk on board',
#        'oil on panel and oil on canvas', 'oil and temple on board',
#        'oil on paper mounted on masonite', 'oil and paper on masonite',
#        'atl colors on canvas laid down on board',
#        'acrylic on corrugated board and acrylic on paper mounted on board',
#        'oil and polytec on masonite', 'oil on canvas laid down on wood',
#        'tempera on wood veneer and amate paper laid down on masonite',
#        'paint on burlap', 'oil on leather',
#        'acrylic on panel, nylon and aluminum',
#        'oil and gouache on canvas', 'pastel and charcoal on canvas',
#        'oil on\xa0aluminum',
#        'pastel, tempera, colored pencil and charcoal on board',
#        'pyroxylin on panel', 'oil on\xa0canvas', 'photographs',
#        'acrylic, pastel and fabric collage on canvas',
#        'conte crayon and pastel on newsprint laid on board',
#        'acrylic and newspaper collage on canvas',
#        'pyroxyline on paper laid on masonite',
#        'cardboard portfolio containing twenty photolithographs',
#        'acrylic paint on panel, and painted metal rods',
#        'oil and pastel on linen', 'plexiglass', 'acrylic on paper',
#        'oil on paper on canvas', 'masonite',
#        'charcoal, oil and sanguine on gessoed masonite',
#        'oil on board mounted on aluminum', 'ink on incised wood',
#        'pastel and mixed media on cardboard',
#        'oil and color oil pastels on canvas',
#        'acrylic and oilstick on canvas', 'two oils on canvas',
#        'diluted oil and tempera on cardboard',
#        'oil and graphite on canvas canvas',
#        'oil on cardboard adhered to canvas',
#        'acrylic and gouache on paper laid down on panel', 'oil / canvas',
#        'oil on photograph laid on panel', 'mixed media on newsprint',
#        'oil on cardboard glued to wood', 'oil and tempera on\xa0burlap',
#        'pyroxylin and acrylic on masonite',
#        'gouache on incised fossilized stone, in two parts',
#        'pyroxylin on masonite', 'oil on cardaaboard',
#        'graphite on artist board', 'oil and grease pencil on canvas',
#        'oil and pastel on canvas', 'oil on canvas adhered to panel',
#        'acrylic and marker on canvas', 'casein on board',
#        'oil on canaavas', 'casein on paper laid down on board',
#        'oil painting on canvas.', 'oil/canvas',
#        'mixed media on bainbridge board', 'pyroxylin on fibracel',
#        'oil and acrylic on masonite',
#        'silkscreen on cardboard, collage, wire, needle and knitting thread',
#        'oil on double-sided cardboard',
#        'oil and sand on paper laid down on canvas',
#        'pyroxylin on novopan', 'oil and glitter on canvas',
#        'oil on paper laid on board',
#        'tempera on heavy paper laid on canvas',
#        'mixed media on paper laid on canvas',
#        'tempera and charcoal on board',
#        'acrylic on cardboard laid down on canvasboard board',
#        'gouache on paper laid down on masonite', 'oil painting on board',
#        'oil on canvas, mounted to board',
#        'tempera and conte crayon on board', 'oil on wood and metal',
#        'oil and sand on paper mounted on masonite', 'acrylate on wood',
#        'oils on canvas', 'pastel and gouache',
#        'oil on silk paper marouflaged on canvas',
#        "oil and pastel on binder's board",
#        'mixed technique, charcoal, ink on cardboard',
#        'mixed media on linen canvas', 'gouache on paper mounted to panel',
#        'screenprint on white enamel painted wood with hanging metal rod',
#        'pastel pasted on canvas', 'oil on pavatex',
#        'pastel on linen mounted on board', 'mixed technique',
#        'mixed media sketch', 'oil on canvas, relined',
#        'watercolor and charcoal on canvas', 'oil and tempera on canvas',
#        'tempera, conte crayon and brush and ink on paper laid down on board',
#        'tempera on cardboard mounted on board',
#        'oil on card laid down on canvas',
#        'household paint, metal rods and nylon string on wood',
#        'each: oil on canvas',
#        'painted wood, steel and painted steel elements with nylon string',
#        'charcoal and cake on canvas', 'oil on cardboard mounted on panel',
#        'charcoal and pastel on canvas', 'oil and collage on canvas',
#        'oil and silk paper maroufle on canvas', 'oil on masonite panel',
#        'oil and pastel on masonite panel',
#        'mixed technique on paper mounted on canvas',
#        'oil and sand on canvas\xa0', 'oil and marble dust on canvas',
#        'tempera on paper laid to board',
#        'acrylic multiple with screenprinting in blue and black',
#        'acrylic glass and metal on painted panel',
#        'painted metal rods, nylon thread and wood', 'canvas',
#        'pyroxylin on paper laid down on board',
#        'gouache and watercolor on paper laid down on canvas',
#        'acrylic on wood, metal rods, nylon cords',
#        'metal rods attached to nylon threads in front of silkscreen on aluminium',
#        'white chipboard with black imprint',
#        'oil on cardboard laid down on panel',
#        'oil on cardboard laid down on board',
#        'pyroxylin and acrylic on panel',
#        'oil and newspaper collage on canvas',
#        'oil, sand and metal on canvas',
#        'oil and tempera on burlap mounted on metal',
#        'acrylic, charcoal and pastel on canvas', 'oil on agglomerate',
#        'oil on thick board.', 'oil on panel.',
#        'oil and gold leaf on canvas', 'acrylic and metal on wood',
#        'mixed technique on half board', 'pyroxylin on wood',
#        'tempera on linen',
#        'multiple with metal element on nylon string attached to painted wood',
#        'acrylic on triplay',
#        'acrylic on wood panel with painted metal and nylon string',
#        'wood', 'painted wood with wire elements',
#        'oil on canvas mounted on masonite',
#        'marker and coloured ink acrylic on canvas',
#        'acrylic and mixed technique on paper mounted on cardboard',
#        'oil and acrylic on newspaper laid down on canvas',
#        'mixed technique on canvas', 'pyroxilin on masonite',
#        'oil and sand on paper laid on canvas',
#        'serigraph, silkscreen on paper on masonite',
#        'oil and tempera on burlap',
#        'oil on cardboard laid down on fiber board',
#        'oil on newspaper mounted on canvas',
#        'acrylic on newspaper mounted on canvas', 'oil on burlap canvas',
#        'gouache on fiberboard',
#        'gouache on paper pasted on painted cardboard',
#        'oil and metal on board',
#        'acrylic, pastel, and cloth collage on canvas',
#        'acrylic on wood panel', 'pyroxylin on board',
#        'oil on cardboard mounted on board',
#        'gouache and oil on paper laid on panel',
#        'tempera on paper laid down on cardboard',
#        'incised oil and encaustic on gessoed wood',
#        'gouache and gold leaf on paper laid on canvas',
#        'pastel on paper on canvas', 'pastel on paper mounted on canvas',
#        'oil on paper laid on canvas', 'tempera and pastel on cardboard',
#        'pastel and tempera on cardboard',
#        'oil on canvas mounted on cardboard',
#        'acrylic and wooden elements on panel',
#        'acrylic and fabric collage on canvas',
#        'tempera on paper mounted on masonite',
#        'oil on cardboard mounted on canvas',
#        'oil, sand, and ink on canvas laid on masonite',
#        'gouache and charcoal on newsprint laid down on board',
#        'gouache, watercolor, and ink on paper laid down on canvas',
#        'oil on tin', 'tempera and conte crayon on cardboard',
#        'tempera and conte crayon on newsprint laid down on cardboard',
#        'acrylic, pastel and ink on canvas',
#        'acrylic on aluminum and wood', 'gouache on canvas',
#        'pyroxilin on panel', 'painted wood, metal rod with nylon strings',
#        'tempera, charcoal and pastel on newsprint on board',
#        'painted wood and metal', 'watercolor, gouache and ink',
#        'oil and staples on cardboard mounted on panel',
#        'tempera, pastel and charcoal on board',
#        'oil, newsprint and paper on canvas',
#        'acrylic and oil on masonite',
#        'oil and sand on heavy paper laid on masonite',
#        'acrylic on paper laid on board', 'oil and sand on wood board',
#        'watercolor on paper laid down on board',
#        'painted metal on wood panel', 'ceramic mural',
#        'tempera and conte crayon on newsprint glued to board',
#        'wood, black veneer, leather', 'ink on canvas',
#        'oil and newspaper on canvas and wood',
#        'mixed media and collage on canvas', 'perspex, steel',
#        'oil on paper laid on masonite',
#        'black crayon and tempera on zinc panel',
#        'acrylic on paper laid on masonite',
#        'tempera and charcoal on canvas',
#        'gouache and watercolor on heavy paper laid down on board',
#        'tempera and conte crayon on newsprint laid down on board',
#        'oil on cement composite board', 'painted metal and wood',
#        'acrylic on wood panel, metal and nylon string',
#        'charcoal on board',
#        'painted wood with painted metal rod and nylon string',
#        'gouache and ink on paper laid down on cardboard',
#        'oil and acrylic on paper laid down on canvas',
#        'watercolor, gouache and ink on paper laid down on canvas',
#        'watercolor, gouache and casein on paperboard laid down on plywood',
#        'oil, metal bars and son nylon panel mounted',
#        'oil on cardboard laid on panel',
#        'acrylic on wood with painted metal and nylon string',
#        'gouache, ink, crayon, and graphite on board',
#        'gouache on paper, laid on unstretched canvas', 'panel',
#        'oil and charcoal on canvas',
#        'gouache, brush and ink, and gray wash on heavy card',
#        'acrylic on paper laid down on balsa wood board',
#        'mixed media on newspaper laid on canvas',
#        'gouache on paper/board', 'painted metal elements on wood panel',
#        'gouache on carton',
#        'watercolour and charcoal laid down on canvas',
#        'acrylic and metal on wood panel',
#        'acrylic and grease pencil on canvas',
#        'watercolor and graphite on paper mounted on canvas',
#        'pyroxyline on masonite', 'pastel and fabric collage on canvas',
#        'tempera and oil on paper laid down on canvas',
#        'watercolour on ivory', 'mixed mediaoil and fabric on panel',
#        'acrylic on paper laid down on masonite panel',
#        'oil on paper laid on card board',
#        'watercolor and gouache on paper laid on canvas',
#        'pastel on paper mounted on board',
#        'gouache, pastel and charcoal on board',
#        'oil and enamel on canvas',
#        'tempera and india ink on colored canvas board',
#        'tempera and graphite on newsprint laid down on board',
#        'object, wood, painted metal',
#        'oil on silk paper laid down on canvas',
#        'pastel on paper laid down on board',
#        'painted wood, aluminum and nylon strings',
#        'gouache, watercolor and ink on paper laid down on canvas',
#        'pastel on burlap mounted on canvas',
#        'acrylic on wood, nylon string and painted metal',
#        'oil on board mounted on wood panel',
#        'oil and tempera on paper laid down on board',
#        'acrylic on wood with nylon string and metal elements',
#        'oil on board laid down on panel',
#        'oil and newsprint collage on canvas',
#        'acrylic and collage on canvas',
#        'charcoal and crayon on paper mounted on masonite',
#        'tempera and oil on canvas board', 'oil on incised wood panel',
#        'copper relief plaque', 'metal, plastic, and nylon wire',
#        'oil and acrylic on newsprint pasted on canvas',
#        'gouache and collage on paper laid down on cardboard',
#        'pastel and fusain on canvas', 'acrylic and pastel on canvas',
#        'oil and sand on board laid down on masonite',
#        'oil and\xa0sand on board',
#        'oil and sand on panel laid down on\xa0wood',
#        'pastel on heavy paper laid down on canvas',
#        'oil and\xa0sand on canvas',
#        'oil, ink and watercolor on canvas laid down on masonite',
#        'oil and sand\xa0on canvas', 'oil on board mounted on masonite',
#        'pyroxyline on wood panel',
#        'gouache and watercolor on royal linen bond',
#        'brick and acrylic paint', 'acrylic on cardboard',
#        'watercolor and gouache on paper laid down on paper board',
#        'acrylic and watercolor on canvas',
#        'oil on tissue paper mounted on canvas',
#        'watercolor and black chalk on paper laid on masonite',
#        'plaka on paper laid on masonite',
#        'acrylic, pastel and charcoal on canvas',
#        'gouache, pastel and charcoal on cardboard mounted on board',
#        'oil on card mounted on board',
#        'tempera and gouache on paper mounted on canvas',
#        'watercolor on rice paper mounted on canvas',
#        'acrylic on paper laid down on masonite',
#        'mixed media on paper mounted on canvas',
#        'pastels and acrylic colors on paper mounted on canvas',
#        'acrylic, wood metal painted on panel',
#        'oil and gold foil on wood panel',
#        'sand, gouache, watercolor, and ink on paper laid down on canvas',
#        'tempera on newsprint laid down on board',
#        'oil and sand on canvas mounted on masonite',
#        'tempera, chalk and charcoal on burlap',
#        'ink, watercolor and gouache',
#        'acrylic on wood panel, painted metal and nylon string',
#        'acrylic, fabric collage, pastel, and graphite on canvas',
#        'casein on wood',
#        'tempera and conte crayon on paper laid on cardboard',
#        'oil and graphite on canvas laid on panel',
#        'fusain and pastel on canvas', 'tempera on board laid on panel',
#        'pencil and acrylic on paper laid down on board',
#        'watercolor on paper laid down on masonite',
#        'gouache, pastel and colored-pencil on board',
#        'conte crayon and tempera on newsprint laid on board',
#        'graphite and oil on masonite',
#        'graphite and oil on masonite laid on wood panel',
#        'wire, ink and oil on masonite panel',
#        'tempera and conte crayon on the los angeles times newsprint laid on cardboard',
#        'oil and paper collage on canvas',
#        'metal on painted wood and board', 'cut-out amate paper',
#        'tempera and conte crayon on the new york times newsprint (september 8, 1935) laid on cardboard',
#        "oil on wood with wooden artist's frame",
#        'watercolor and gouache on paper mounted on cardboard',
#        'gouache on paper laid down on canvas paper',
#        'gouache and pyroxilin on masonite',
#        'mixed media on paper/ canvas',
#        'oil and gouache on paper laid down on wood',
#        'tempera and ink on card on coloured faesite',
#        'acrylic on newspaper mounted to canvas',
#        'gouache on paper, laid down on masonite',
#        'mixed media with metal, wood, painted',
#        'oil, ink and sand on masonite',
#        'oil and sand on paper laid on masonite',
#        'oil on heavy cardboard laid on canvas',
#        'pastel on paper laid on canvas',
#        'gouache and graphite on paper laid on cardboard',
#        'acrylic, pastel and cloth on canvas', 'distemper on heavy paper',
#        'oil on board laid down on wood',
#        'gouache and conte crayon on paper laid down on board',
#        'mixed media on paper laid down on canvas',
#        'gouache on paper board', 'gouache and ink',
#        'acrylic on paper mounted on canvas', 'acrylic on plywood',
#        'acrylic on paper on canvas', 'painting on wood',
#        'encaustic on wood', 'mix on wood', 'mix on masonite',
#        'oil on mahogany panel', 'wood and painted metal',
#        'oil on burlap laid down on canvas', 'pyroxilin on wood panel',
#        'watercolor on paper laid on masonite',
#        'oil on canvas laid on masonite',
#        'gouache and acrylic on paper laid on board',
#        'gouache on cardboard laid on panel',
#        'tempera, charcoal and gouache on cardboard mounted on wallboard',
#        'tempera and conte crayon on newsprint laid on paper board',
#        'oil on composite wood board',
#        'metal rods and nylon threads on painted panel',
#        'varnished wires and tempera on canvas',
#        'pyroxilin on paper laid down on wood',
#        'graphite and color pencil on tissue paper laid down on masonite',
#        'oil and sand on heavy paper laid down on masonite',
#        'aluminum and nylon',
#        'oil and gouache on heavy paper laid down on canvas',
#        'acrylic, metal rods and nylon strings on wood panel',
#        'watercolor and tempera on paper laid down on canvas',
#        'gouache and watercolor on board',
#        'acrylic, nylon wire, wood and aluminum on wood panel',
#        'oil on circular panel mounted to panel',
#        "oil on canvas laid on wood panel in the artist's original wooden frame",
#        'pyroxilin on wood panel and iron frame',
#        'acrylic on canvas laid on board',
#        'acrylic and gouache on paper laid down on wood',
#        'bois peint, metal et fil de fer',
#        'oil on cardboard laid down on styrofoam',
#        'oil and tempera on canvas laid down on cardboard',
#        'painted wood, plaster and metal wire construction',
#        'pyroxiline on wood',
#        'pyroxiline and oil on board mounted on masonite',
#        'gouache, ink and oil on paper laid on canvas',
#        'oil and tape on masonite', 'oil and sand on burlap',
#        'painted wood, metal and nylon',
#        'gouache and copper leaf on paper', 'oil on gessoed burlap',
#        'oil on museum canvas panel', 'pyroxilin on board',
#        'painted wood, steel and nylon',
#        'ebony, painted ebony, painted cardboard, shaped metal.',
#        'acrylic on board with metal, nylon thread and painted metal filaments',
#        'oil on panel and metal wire', 'pastel on paper on linen',
#        'acrylic on canvasboard', 'tempera on concrete',
#        'oil and sand on linen', 'steel and nylon',
#        'tempera and watercolor on board mounted on panel',
#        'gouache, ink, crayon and graphite on board',
#        'crayon and charcoal on ivory paper',
#        'tempera on paper laid down on canvas', 'pyroxilin on wood',
#        'conte crayon and ink on canvas', 'oil and sand on wood panel',
#        'charcoal, pastel and gouache on wood panel',
#        'fili metallici verniciati e tempera su tela',
#        'tempera su tavola e metallo dipinto', 'oil on plywood panel',
#        'oil on plywood',
#        'ink, oil and metallic paint on paper laid down on board',
#        'oil on panel with painted metal and nylon wire',
#        'acrylic on newsprint collage laid down on canvas',
#        'piroxyline on paper laid on masonite', 'incised wood',
#        'wood, aluminium and nylon', 'oil and metal on panel',
#        'oil on board laid down on board', 'oil and panel with metal bar',
#        'oil on panel, metal and nylon wire', 'oil, metal and wood',
#        'pyroxiline on masonite',
#        'ink, gouache and pencil on paper laid down on board',
#        'black crayon and white tempera on zinc plate',
#        'acrylic on paper laid down on canvas',
#        'goauche and pastel on paper laid down on masonite',
#        'chalk, gouache and oil on paper laid down on canvas',
#        'black marker pen and gouache on paper laid down on canvas',
#        'charcoal and oil on various sheets of newspaper laid down on canvas',
#        'pyroxilin on hinged panels',
#        'painted wood construction with metal and nylon attachments',
#        'aluminium, oil and wood consrtuction',
#        'gouache on paper and wood', 'piroxilin on masonite',
#        'oil and sand on canvas laid down on masonite',
#        'vinyl on masonite and triplay',
#        'watercolor, gouache and pastel on board',
#        'gouache and sand on paper laid down on board',
#        'pyroxyline on panel', 'oil and sand on panel',
#        'acrylic on newsprint laid down on canvas',
#        'oil, sand and paper collage on masonite',
#        'oil and gouache on paper',
#        'pastel and acrylic on paper laid down on canvas'], dtype=object)

# %% [markdown]
# # Clean nombres artistas
#
# - from the MutualArtLimpio.csv dataset hay 95 artistas diferentes (con solo obras vendidas)
# -

# %% [markdown]
# artistas que deberían hacer match
# - cesar villacres -> cesar a.villacres
# - emiliano di cavalcanti -> emiliano de cavalvanti
# - graciela rodo-boulanger -> graciela rodo boulanger
# - ignacio iturria -> ignacio de iturria
# - jesus-rafael soto -> jesus rafael soto
# - joaquin torres garcia -> joaquin torres-garcia
# - jose maria mijares -> jose mijares
# - leopoldo romanac -> leopoldo romaã‘ach
# - ricardo martinez de hoyos -> ricardo martinez

# %%
def clean_autor(df):
    '''
    Limpiar artistas de mutual art y los modifica para
    ser iguales a la lista de artistas acordada
    
    Es probable que se tenga que modificar esta función para añadir nombres adicionales.
    Hay artistas que no son de la lista
    
    SUGERENCIA: quitarle los guiones a todos los nombres (de la tabla de referencia)
    '''
    df['autor'] = df['autor'].str.replace('cesar villacres', 'cesar a. villacres')
    df['autor'] = df['autor'].str.replace('emiliano di cavalcanti', 'emiliano de cavalcanti')
    df['autor'] = df['autor'].str.replace('graciela rodo-boulanger', 'graciela rodo boulanger')
    df['autor'] = df['autor'].str.replace('jesus-rafael soto', 'jesus rafael soto')
    df['autor'] = df['autor'].str.replace('joaquin torres garcia', 'joaquin torres-garcia')
    df['autor'] = df['autor'].str.replace('ignacio iturria', 'ignacio de iturria')
    df['autor'] = df['autor'].str.replace('jose maria mijares', 'jose mijares')
    df['autor'] = df['autor'].str.replace('leopoldo romanac', 'leopoldo romanach')
    df['autor'] = df['autor'].str.replace('ricardo martinez de hoyos', 'ricardo martinez')
        
    return df

# %%
len(df['autor'].unique())
# Out:
# 95

# %%
df_artistas['autor'] = df_artistas['name']+' '+df_artistas['last_name']
#df_artistas

# %%
df = clean_autor(df)

ma_authors = df.groupby(['autor']).count()['ID'].reset_index()
ma_authors.sort_values(by=['ID'], ascending=False)
ma_authors['temp_col'] = 1

# %%
merged_df = ma_authors.merge(df_artistas, how='outer', on='autor')
#merged_df[merged_df['autor']]
merged_df.shape
# Out:
# (144, 8)

# %%
len(merged_df[merged_df['temp_col'].isna() == True].sort_values(by=['autor']))

#tabla de artistas que no hiciaron match con mutual art

#sacar datos de esos 50 artistas que faltan
# Out:
# 49

# %%
len(merged_df[merged_df['name'].isna() == True])

#38 artistas de la lista de artistas que no hacen match con datos de mutual art
#58 de mart que no hacen match con la lista de artistas

#lista de mut art que no hicieron match con la lista de autores
# Out:
# 29

# %% [markdown]
# # Clean dimensiones
# (height va primero)
#
# Extraer las dimensiones de la columna dimensiones y pasarlas a centímetros

# %%
def fraction_char_replace(s):
    '''
    Reemplaza las fracciones representadas como un solo caracter y las convierte en decimales
    ej: ¾, ½ se convierten en .75 y .5
    Args: 
        s(str)- string de las dimensiones de una obra
    '''
    
    for c in s:
        try:
            name = unicodedata.name(c)
        except ValueError:
            continue
        if name.startswith('VULGAR FRACTION'):
            normalized = unicodedata.normalize('NFKC', c)
            numerator, _slash, denominator = normalized.partition('⁄')
            
            frac = int(numerator)/int(denominator)
            s = s.replace(c, str(frac))
            #yield c, numerator, denominator
            
            
    return s
            
#TO-DO
#- encontrar source de la fuente

# %%
def fraction_str_replace(s):
    '''
    Se asume que dentro de cada registro, se encuentra un 
    Formas de detectat una fraccion de la forma a/b:
    
    num a/b
    
    aaa/b
    
    num-a/b
    
    num.a/b
    
    ojo: existe .groups()
    '''
    if(re.search(' [0-9]?[0-9]/[0-9]?[0-9]', s)):  #tipo num a/b
        
        #es un ciclo porque se debe de tratar cada fraccion en todo el string
        for m in re.findall('([0-9]?[0-9])/([0-9]?[0-9])',s): #lista de tuplas para cada fracción
            num, denom = int(m[0]), int(m[1])
            frac = num/denom
            frac = re.sub('0','',str(frac))
            
            pattern = ' '+str(num)+'/'+str(denom)
            
            s = re.sub(pattern, frac,s)
        
    elif(re.search('[0-9][0-9]{2}?/[0-9][0-9]?',s)): #tipo aaa/b
        
        for m in re.findall('([0-9][0-9][0-9])/([0-9][0-9]?)',s): #lista de tuplas para cada fracción
            num, denom = int(m[0]), int(m[1])
            frac = num/denom
            pattern = str(num)+'/'+str(denom)
            
            s = re.sub(pattern, str(frac),s)
        
    elif(re.search('[0-9][0-9]?-[0-9][0-9]?/[0-9]?[0-9]',s)):
        #tipo num-a/b
        
        for m in re.findall('([0-9][0-9]?[0-9]?)/([0-9][0-9]?)',s): #lista de tuplas para cada fracción
            num, denom = int(m[0]), int(m[1])
            frac = num/denom
            frac = re.sub('0','',str(frac))
            pattern = '-'+str(num)+'/'+str(denom)
            
            s = re.sub(pattern, frac,s)
        
    elif(re.search('[0-9]\.[0-9][0-9]?/[0-9]?[0-9]',s)):
        #tipo num.a/b
        
        for m in re.findall('([0-9][0-9]?[0-9]?)/([0-9][0-9]?)',s): #lista de tuplas para cada fracción
            num, denom = int(m[0]), int(m[1])
            frac = num/denom
            frac = re.sub('0\.','',str(frac))
            pattern = str(num)+'/'+str(denom)
            
            s = re.sub(pattern, frac,s)
        
    else: 
        resp = 'no se detectó'
    
    return s

#TO-DO:
#simplificar código
#talvez se pueden hacer menos ifs
#mejorar comentarios

# %%
#test de la funcion anterior

#fracciones = df[df['dimensiones'].str.contains('[0-9]\/[0-9]') == True].copy()#.head(5)
#fracciones['tipo_frac'] = fracciones.dimensiones.apply(lambda x: fraction_str_replace(x))

# %%
#fracciones
#ejem = fracciones.iloc[2]['dimensiones']

# %%
def is_inches(s):
    '''
    
    '''
    no_measures_ids = ['various sizes', 'dimensions variable', 'property from the estate of bernard chappard\xa0 ...']
    inches_ids = ['in', '"', '\'\'', '″',  'a']
    cm_ids = ['cm', 'mm', 'm']
    
    if any(keyword in s for keyword in inches_ids):
        is_inch = 1
    elif any(keyword in s for keyword in cm_ids):
        is_inch = 0
    elif any(keyword in s for keyword in no_measures_ids):
        is_inch = -1
    else: 
        is_inch = 1 #if no imformation is given of it's measurements, it is assumed that the measures are in inches
        #is_inch = 2 #in case if a problem is detected and some rows need to be flagged
    
    return is_inch

# %%
def extract_numbers(df):
    '''
    Se extrae los primeros 2 valores numéricos que se encuentre. Se asumen 3 cosas:
    
    - que no hay obras de 3 dimensiones (esculturas, etc...)
    - si vienen las medidas 2 veces, primero se observan las pulgadas
    '''
    df['height'] = df.dimensiones.str.extract('([0-9][0-9]?[0-9]?\.?[0-9]?[0-9]?[0-9]?)') #normalmente se extrae el primer match
    temp_series = df.dimensiones.str.replace('[0-9][0-9]?[0-9]?\.?[0-9]?[0-9]?[0-9]?', '',regex=True, n=1)
    df['height'] = pd.to_numeric(df['height'])
    df['width'] = temp_series.str.extract('([0-9][0-9]?[0-9]?\.?[0-9]?[0-9]?[0-9]?)')
    df['width'] = pd.to_numeric(df['width'])
    
    return df
    #que las pase como números

# %%
def clean_dimensiones(df):
    '''
    Limpia la columna dimensiones y agrega las columnas de height y width.
    Se convierten las columnas a cm si están en inches
    
    '''
    df['dimensiones'] = df.dimensiones.apply(lambda x: fraction_char_replace(x))
    df['dimensiones'] = df.dimensiones.apply(lambda x: fraction_str_replace(x))
    df['is_inch'] = df.dimensiones.apply(lambda x: is_inches(x))
    df = extract_numbers(df)
    
    return df

# %%
df_clean = clean_dimensiones(df)

# %%
df_clean_2 = extract_numbers(df_clean)

# %%
len(df['casa subasta'].unique())
# Out:
# 263
